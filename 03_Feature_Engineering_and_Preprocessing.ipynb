# %%
# ==========================================================
# PID1 - Import Required Libraries
# ==========================================================

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries Loaded Successfully")
# Out:
# Libraries Loaded Successfully

# %%
# ==========================================================
# PID2 - Load ML Ready Dataset
# ==========================================================

output_path = "C:/Users/kalya/NTCC/NHANES/CVD_ML_python/Outputs/"

df = pd.read_csv(output_path + "ML_READY_DATASET.csv")

print("Dataset Loaded Successfully")
print(f"Shape : {df.shape}")
# Out:
# Dataset Loaded Successfully
# Shape : (15457, 643)

# %%
# ==========================================================
# PID3 - Dataset Verification
# ==========================================================

print("="*60)
print("DATASET INFORMATION")
print("="*60)

print(df.info())

print("\n")

print("="*60)
print("TARGET DISTRIBUTION")
print("="*60)

print(df["Composite_CVD"].value_counts())

print("\nPercentage")

print(round(df["Composite_CVD"].value_counts(normalize=True)*100,2))

print("\n")

print("Missing Values :", df.isnull().sum().sum())
# Out:
# ...
# DATASET INFORMATION
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15457 entries, 0 to 15456
# Columns: 643 entries, SEQN to Composite_CVD
# dtypes: float64(203), int64(440)
# memory usage: 75.8 MB
# None
#
#
# ...
# TARGET DISTRIBUTION
# ...
# Composite_CVD
# 0    14331
# 1     1126
# Name: count, dtype: int64
#
# Percentage
# Composite_CVD
# 0    92.72
# 1     7.28
# Name: proportion, dtype: float64
#
#
# Missing Values : 0

# %%
# ==========================================================
# PID4 - Separate Features and Target
# ==========================================================

X = df.drop(columns=["Composite_CVD"])

y = df["Composite_CVD"]

print("Feature Matrix :", X.shape)

print("Target Vector  :", y.shape)
# Out:
# Feature Matrix : (15457, 642)
# Target Vector  : (15457,)

# %%
# ==========================================================
# PID5 - Identify Numerical and Categorical Features
# ==========================================================

numerical_features = X.select_dtypes(
    include=["int64","float64"]
).columns.tolist()

categorical_features = X.select_dtypes(
    exclude=["int64","float64"]
).columns.tolist()

print("Numerical Features :", len(numerical_features))

print("Categorical Features :", len(categorical_features))
# Out:
# Numerical Features : 642
# Categorical Features : 0

# %%
# ==========================================================
# PID6 - Train Test Split
# ==========================================================

X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.20,

    random_state=42,

    stratify=y

)

print("="*60)
print("TRAINING DATA")
print("="*60)

print(X_train.shape)
print(y_train.shape)

print("\n")

print("="*60)
print("TESTING DATA")
print("="*60)

print(X_test.shape)
print(y_test.shape)
# Out:
# ...
# TRAINING DATA
# ...
# (12365, 642)
# (12365,)
#
#
# ...
# TESTING DATA
# ...
# (3092, 642)
# (3092,)

# %%
# ==========================================================
# PID7 - Verify Class Distribution
# ==========================================================

print("Training")

print(round(y_train.value_counts(normalize=True)*100,2))

print("\n")

print("Testing")

print(round(y_test.value_counts(normalize=True)*100,2))
# Out:
# Training
# Composite_CVD
# 0    92.71
# 1     7.29
# Name: proportion, dtype: float64
#
#
# Testing
# Composite_CVD
# 0    92.72
# 1     7.28
# Name: proportion, dtype: float64

# %%
# ==========================================================
# PID8 - Save Train and Test Datasets
# ==========================================================

X_train.to_csv(output_path + "X_train.csv", index=False)

X_test.to_csv(output_path + "X_test.csv", index=False)

y_train.to_frame(name="Composite_CVD").to_csv(
    output_path + "y_train.csv",
    index=False
)

y_test.to_frame(name="Composite_CVD").to_csv(
    output_path + "y_test.csv",
    index=False
)

print("Training and Testing datasets saved successfully.")
# Out:
# Training and Testing datasets saved successfully.
